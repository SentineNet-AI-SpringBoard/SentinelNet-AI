# %%
import pandas as pd
# mon = pd.read_csv("/content/drive/MyDrive/dataset/Monday-WorkingHours.pcap_ISCX.csv")
# fri1 = pd.read_csv("/content/drive/MyDrive/dataset/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")
# fri2 = pd.read_csv("/content/drive/MyDrive/dataset/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")
# fri3 = pd.read_csv("/content/drive/MyDrive/dataset/Friday-WorkingHours-Morning.pcap_ISCX.csv")
# thu1 = pd.read_csv("/content/drive/MyDrive/dataset/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")
# thu2 = pd.read_csv("/content/drive/MyDrive/dataset/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
# tue = pd.read_csv("/content/drive/MyDrive/dataset/Tuesday-WorkingHours.pcap_ISCX.csv")
wed = pd.read_csv("/content/drive/MyDrive/dataset/Wednesday-workingHours.pcap_ISCX.csv")

# %%
wed.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %%
wed.tail()
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 529913                443           18738                   1
# 529914                 53           60797                   2
# 529915                 53             154                   2
# 529916                 53             155                   2
# 529917              52400              18                   1
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 529913                        1                            6
# 529914                        2                           80
# 529915                        2                           64
# 529916                        2                           80
# 529917                        1                            0
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 529913                             6                       6
# 529914                           156                      40
# ...

# %%
wed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529918 entries, 0 to 529917
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             529918 non-null  int64
#  1    Flow Duration                529918 non-null  int64
#  2    Total Fwd Packets            529918 non-null  int64
#  3    Total Backward Packets       529918 non-null  int64
#  4   Total Length of Fwd Packets   529918 non-null  int64
#  5    Total Length of Bwd Packets  529918 non-null  int64
#  6    Fwd Packet Length Max        529918 non-null  int64
#  7    Fwd Packet Length Min        529918 non-null  int64
#  8    Fwd Packet Length Mean       529918 non-null  float64
#  9    Fwd Packet Length Std        529918 non-null  float64
#  10  Bwd Packet Length Max         529918 non-null  int64
#  11   Bwd Packet Length Min        529918 non-null  int64
# ...

# %%
wed.shape
# Out:
# (529918, 79)

# %%
#get column name of mon.
wed.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
#Data types check
wed.dtypes
# Out:
#  Destination Port                int64
#  Flow Duration                   int64
#  Total Fwd Packets               int64
#  Total Backward Packets          int64
# Total Length of Fwd Packets      int64
#                                 ...
# Idle Mean                      float64
#  Idle Std                      float64
#  Idle Max                        int64
#  Idle Min                        int64
#  Label                          object
# Length: 79, dtype: object

# %%
#basic info
wed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529918 entries, 0 to 529917
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             529918 non-null  int64
#  1    Flow Duration                529918 non-null  int64
#  2    Total Fwd Packets            529918 non-null  int64
#  3    Total Backward Packets       529918 non-null  int64
#  4   Total Length of Fwd Packets   529918 non-null  int64
#  5    Total Length of Bwd Packets  529918 non-null  int64
#  6    Fwd Packet Length Max        529918 non-null  int64
#  7    Fwd Packet Length Min        529918 non-null  int64
#  8    Fwd Packet Length Mean       529918 non-null  float64
#  9    Fwd Packet Length Std        529918 non-null  float64
#  10  Bwd Packet Length Max         529918 non-null  int64
#  11   Bwd Packet Length Min        529918 non-null  int64
# ...

# %%
#basic statistics
wed.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      529918.000000    5.299180e+05       529918.000000
# mean        10644.367112    1.038927e+07           10.390315
# std         21390.213475    2.875195e+07          892.412791
# min             0.000000   -1.000000e+00            1.000000
# 25%            53.000000    1.760000e+02            2.000000
# 50%            80.000000    3.130300e+04            2.000000
# 75%           443.000000    3.557448e+05            4.000000
# max         65535.000000    1.200000e+08       219759.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            529918.000000                 5.299180e+05
# mean                 11.517105                 5.324195e+02
# std                1173.318788                 6.228642e+03
# min                   0.000000                 0.000000e+00
# 25%                   1.000000                 1.800000e+01
# ...

# %%
#identify missing values
wed.isnull().sum()
# Out:
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
#  Label                         0
# Length: 79, dtype: int64

# %%
#visualize missing values
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.heatmap(mon.isnull(), cbar=True, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %%
#check and drop duplicates
wed.duplicated().sum()
# Out:
# np.int64(0)

# %%
wed = mon.drop_duplicates()
wed.duplicated().sum()
# Out:
# np.int64(0)

# %%
#drop irrelevant features
irrelevant = ["Flow ID", "Source IP", "Destination IP", "Timestamp"]
wed = mon.drop(columns=[c for c in irrelevant if c in mon.columns], errors='ignore')
#check remaining columns
wed.shape[1]
# Out:
# 79

# %%
wed.to_csv("/content/cleaned_wed.csv", index=False)
print("Cleaned dataset saved as cleaned_wed.csv")
# Out:
# Cleaned dataset saved as cleaned_monday.csv

# %%
#convert only numeric columns
import numpy as np
num_df = mon.select_dtypes(include=[np.number])
#correlation matrix
corr = num_df.corr()
#heatmap
plt.figure(figsize=(12,8))
plt.imshow(corr, cmap="coolwarm", interpolation="nearest")
plt.colorbar(label="Correlation")
plt.title("Correlation Heatmap")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()
#also show top correlated pairs
corr_unstacked = corr.unstack().sort_values(ascending=False)
print("\nTop correlated features:\n", corr_unstacked.drop_duplicates().head(10))
# Out:
# Top correlated features:
#  Active Mean              Active Mean                     1.000000
#  Bwd Packet Length Mean   Avg Bwd Segment Size           1.000000
#  act_data_pkt_fwd         Total Fwd Packets              0.999509
#  Total Backward Packets   act_data_pkt_fwd               0.999453
#  Subflow Bwd Packets     Subflow Fwd Packets             0.999322
#  Total Backward Packets  Subflow Fwd Packets             0.999322
# Subflow Fwd Packets       Total Length of Bwd Packets    0.999020
#  Subflow Bwd Bytes        Total Fwd Packets              0.999020
#  act_data_pkt_fwd         Total Length of Bwd Packets    0.998436
# Fwd IAT Total             Flow Duration                  0.997429
# dtype: float64

# %%
#outlier detection\
# With boxplot
plt.figure(figsize=(6,4))
plt.boxplot(num_df[' Flow Duration'], vert=False)
plt.title("Outliers in Flow Duration")
plt.show()

# %%
#feature Importance
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
#encode the target column "Label"
le = LabelEncoder()
mon[' Label'] = le.fit_transform(wed[' Label'])
#split into x and y
X = wed.drop(columns=[' Label'])
y = wed[' Label']
#clean the feature data
X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(0)

#show top and bottom features
print("Top 10 Important Features:\n", important_feats.head(10))
print("\nLeast Important Features:\n", important_feats.tail(10))
# Out:
# Top 10 Important Features:
#   Destination Port               0.0
#  Flow Duration                  0.0
#  Total Fwd Packets              0.0
#  Total Backward Packets         0.0
# Total Length of Fwd Packets     0.0
#  Total Length of Bwd Packets    0.0
#  Fwd Packet Length Max          0.0
#  Fwd Packet Length Min          0.0
#  Fwd Packet Length Mean         0.0
#  Fwd Packet Length Std          0.0
# dtype: float64
#
# Least Important Features:
#   act_data_pkt_fwd        0.0
#  min_seg_size_forward    0.0
# Active Mean              0.0
#  Active Std              0.0
#  Active Max              0.0
#  Active Min              0.0
# Idle Mean                0.0
#  Idle Std                0.0
#  Idle Max                0.0
#  Idle Min                0.0
# dtype: float64

# %%
#identify categorical and numerical features
cat_features = wed.select_dtypes(include=['object']).columns.tolist()
num_features = wed.select_dtypes(include=[np.number]).columns.tolist()
print("\nCategorical Features:", cat_features)
print("\nNumerical Features:", num_features[:10])
# Out:
# Categorical Features: []
#
# Numerical Features: [' Destination Port', ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets', 'Total Length of Fwd Packets', ' Total Length of Bwd Packets', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Fwd Packet Length Mean', ' Fwd Packet Length Std']

# %%
#encoding categorical feature
from sklearn.preprocessing import LabelEncoder
for col in cat_features:
    wed[col] = LabelEncoder().fit_transform(wed[col])
print("Categorical features encoded")
#no use as no categorical features. as i have shown above
# Out:
# Categorical features encoded

# %%
#flow Duration Distribution
plt.figure(figsize=(6,4))
plt.hist(wed[' Flow Duration'], bins=50, color="skyblue", edgecolor="black")
plt.title("Distribution of Flow Duration")
plt.xlabel("Flow Duration")
plt.ylabel("Count")
plt.show()
#label distribution
plt.figure(figsize=(6,4))
wed[' Label'].value_counts().plot(kind="bar", color=["green", "red"])
plt.title("Label Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
wed.to_csv("/content/wed_encoded.csv", index=False)
print("Final encoded dataset saved as wed_encoded.csv")
# Out:
# Final encoded dataset saved as monday_encoded.csv
