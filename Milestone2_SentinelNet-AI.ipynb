# %%
### SentinelNet-AI-Powered Network Intrusion Detection System (NIDS)
#SentinelNet-AI is an AI-powered Network Intrusion Detection System that uses machine learning to classify network traffic as normal or malicious, helping identify potential cyber-attacks in real time.

# %%
#1.Dataset Acquisition and Exploration
#Dataset used is CICIDS2017 Dataset(Wednesday subset) - https://www.unb.ca/cic/datasets/ids-2017.html

# %%
#import required libraries
import pandas as pd #for data manipulation

# %%
#Load dataset
from google.colab import drive
drive.mount('/content/drive')
file_path = "/content/drive/MyDrive/SentinelNet/Wednesday-workingHours.pcap_ISCX.csv"
df = pd.read_csv(file_path, low_memory=False)
print("dataset loaded")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# dataset loaded

# %%
#dataset shape and preview - display first few rows & check its dimension to get a sense of data structure, no. of columns, and record count.
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (692703, 79)
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# 3                          6660                    1313
# 4                          3152                    1575
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       6                 6.000000                0.000000
# 1                       0                15.636364               31.449238
# 2                       0               315.000000              632.561635
# 3                       0               203.058823              425.778474
# 4                       0               350.000000              694.509719
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     20          0.0          0.0            0
# 1  ...                     32          0.0          0.0            0
# 2  ...                     32          0.0          0.0            0
# 3  ...                     32          0.0          0.0            0
# 4  ...                     32          0.0          0.0            0
#
#     Active Min  Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0            0        0.0        0.0          0          0  BENIGN
# 1            0        0.0        0.0          0          0  BENIGN
# 2            0        0.0        0.0          0          0  BENIGN
# 3            0        0.0        0.0          0          0  BENIGN
# 4            0        0.0        0.0          0          0  BENIGN
#
# [5 rows x 79 columns]

# %%
#Get column name
print("columns:")
df.columns.tolist()
# Out:
# columns:
# [' Destination Port',
#  ' Flow Duration',
#  ' Total Fwd Packets',
#  ' Total Backward Packets',
#  'Total Length of Fwd Packets',
#  ' Total Length of Bwd Packets',
#  ' Fwd Packet Length Max',
#  ' Fwd Packet Length Min',
#  ' Fwd Packet Length Mean',
#  ' Fwd Packet Length Std',
#  'Bwd Packet Length Max',
#  ' Bwd Packet Length Min',
#  ' Bwd Packet Length Mean',
#  ' Bwd Packet Length Std',
#  'Flow Bytes/s',
#  ' Flow Packets/s',
#  ' Flow IAT Mean',
#  ' Flow IAT Std',
#  ' Flow IAT Max',
#  ' Flow IAT Min',
#  'Fwd IAT Total',
#  ' Fwd IAT Mean',
#  ' Fwd IAT Std',
#  ' Fwd IAT Max',
#  ' Fwd IAT Min',
#  'Bwd IAT Total',
#  ' Bwd IAT Mean',
#  ' Bwd IAT Std',
#  ' Bwd IAT Max',
#  ' Bwd IAT Min',
#  'Fwd PSH Flags',
#  ' Bwd PSH Flags',
#  ' Fwd URG Flags',
#  ' Bwd URG Flags',
#  ' Fwd Header Length',
#  ' Bwd Header Length',
#  'Fwd Packets/s',
#  ' Bwd Packets/s',
#  ' Min Packet Length',
#  ' Max Packet Length',
#  ' Packet Length Mean',
#  ' Packet Length Std',
#  ' Packet Length Variance',
#  'FIN Flag Count',
#  ' SYN Flag Count',
#  ' RST Flag Count',
#  ' PSH Flag Count',
#  ' ACK Flag Count',
#  ' URG Flag Count',
#  ' CWE Flag Count',
#  ' ECE Flag Count',
#  ' Down/Up Ratio',
#  ' Average Packet Size',
#  ' Avg Fwd Segment Size',
#  ' Avg Bwd Segment Size',
#  ' Fwd Header Length.1',
#  'Fwd Avg Bytes/Bulk',
#  ' Fwd Avg Packets/Bulk',
#  ' Fwd Avg Bulk Rate',
#  ' Bwd Avg Bytes/Bulk',
#  ' Bwd Avg Packets/Bulk',
#  'Bwd Avg Bulk Rate',
#  'Subflow Fwd Packets',
#  ' Subflow Fwd Bytes',
#  ' Subflow Bwd Packets',
#  ' Subflow Bwd Bytes',
#  'Init_Win_bytes_forward',
#  ' Init_Win_bytes_backward',
#  ' act_data_pkt_fwd',
#  ' min_seg_size_forward',
#  'Active Mean',
#  ' Active Std',
#  ' Active Max',
#  ' Active Min',
#  'Idle Mean',
#  ' Idle Std',
#  ' Idle Max',
#  ' Idle Min',
#  ' Label']

# %%
#datatypes check
print("Column data types:")
print(df.dtypes)
print(df.dtypes.value_counts())
# Out:
# Column data types:
#  Destination Port                int64
#  Flow Duration                   int64
#  Total Fwd Packets               int64
#  Total Backward Packets          int64
# Total Length of Fwd Packets      int64
#                                 ...
# Idle Mean                      float64
#  Idle Std                      float64
#  Idle Max                        int64
#  Idle Min                        int64
#  Label                          object
# Length: 79, dtype: object
# int64      54
# float64    24
# object      1
# Name: count, dtype: int64

# %%
#basic info summary - checking column data types, non-null counts, and memory usage to understand the structure of the dataset and detect inconsistencies.
print("Basic info summary:")
print(df.info())
# Out:
# Basic info summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692703 entries, 0 to 692702
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             692703 non-null  int64
#  1    Flow Duration                692703 non-null  int64
#  2    Total Fwd Packets            692703 non-null  int64
#  3    Total Backward Packets       692703 non-null  int64
#  4   Total Length of Fwd Packets   692703 non-null  int64
#  5    Total Length of Bwd Packets  692703 non-null  int64
#  6    Fwd Packet Length Max        692703 non-null  int64
#  7    Fwd Packet Length Min        692703 non-null  int64
#  8    Fwd Packet Length Mean       692703 non-null  float64
#  9    Fwd Packet Length Std        692703 non-null  float64
#  10  Bwd Packet Length Max         692703 non-null  int64
#  11   Bwd Packet Length Min        692703 non-null  int64
#  12   Bwd Packet Length Mean       692703 non-null  float64
#  13   Bwd Packet Length Std        692703 non-null  float64
#  14  Flow Bytes/s                  691695 non-null  float64
#  15   Flow Packets/s               692703 non-null  float64
#  16   Flow IAT Mean                692703 non-null  float64
#  17   Flow IAT Std                 692703 non-null  float64
#  18   Flow IAT Max                 692703 non-null  int64
#  19   Flow IAT Min                 692703 non-null  int64
#  20  Fwd IAT Total                 692703 non-null  int64
#  21   Fwd IAT Mean                 692703 non-null  float64
#  22   Fwd IAT Std                  692703 non-null  float64
#  23   Fwd IAT Max                  692703 non-null  int64
#  24   Fwd IAT Min                  692703 non-null  int64
#  25  Bwd IAT Total                 692703 non-null  int64
#  26   Bwd IAT Mean                 692703 non-null  float64
#  27   Bwd IAT Std                  692703 non-null  float64
#  28   Bwd IAT Max                  692703 non-null  int64
#  29   Bwd IAT Min                  692703 non-null  int64
#  30  Fwd PSH Flags                 692703 non-null  int64
#  31   Bwd PSH Flags                692703 non-null  int64
#  32   Fwd URG Flags                692703 non-null  int64
#  33   Bwd URG Flags                692703 non-null  int64
#  34   Fwd Header Length            692703 non-null  int64
#  35   Bwd Header Length            692703 non-null  int64
#  36  Fwd Packets/s                 692703 non-null  float64
#  37   Bwd Packets/s                692703 non-null  float64
#  38   Min Packet Length            692703 non-null  int64
#  39   Max Packet Length            692703 non-null  int64
#  40   Packet Length Mean           692703 non-null  float64
#  41   Packet Length Std            692703 non-null  float64
#  42   Packet Length Variance       692703 non-null  float64
#  43  FIN Flag Count                692703 non-null  int64
#  44   SYN Flag Count               692703 non-null  int64
#  45   RST Flag Count               692703 non-null  int64
#  46   PSH Flag Count               692703 non-null  int64
#  47   ACK Flag Count               692703 non-null  int64
#  48   URG Flag Count               692703 non-null  int64
#  49   CWE Flag Count               692703 non-null  int64
#  50   ECE Flag Count               692703 non-null  int64
#  51   Down/Up Ratio                692703 non-null  int64
#  52   Average Packet Size          692703 non-null  float64
#  53   Avg Fwd Segment Size         692703 non-null  float64
#  54   Avg Bwd Segment Size         692703 non-null  float64
#  55   Fwd Header Length.1          692703 non-null  int64
#  56  Fwd Avg Bytes/Bulk            692703 non-null  int64
#  57   Fwd Avg Packets/Bulk         692703 non-null  int64
#  58   Fwd Avg Bulk Rate            692703 non-null  int64
#  59   Bwd Avg Bytes/Bulk           692703 non-null  int64
#  60   Bwd Avg Packets/Bulk         692703 non-null  int64
#  61  Bwd Avg Bulk Rate             692703 non-null  int64
#  62  Subflow Fwd Packets           692703 non-null  int64
#  63   Subflow Fwd Bytes            692703 non-null  int64
#  64   Subflow Bwd Packets          692703 non-null  int64
#  65   Subflow Bwd Bytes            692703 non-null  int64
#  66  Init_Win_bytes_forward        692703 non-null  int64
#  67   Init_Win_bytes_backward      692703 non-null  int64
#  68   act_data_pkt_fwd             692703 non-null  int64
#  69   min_seg_size_forward         692703 non-null  int64
#  70  Active Mean                   692703 non-null  float64
#  71   Active Std                   692703 non-null  float64
#  72   Active Max                   692703 non-null  int64
#  73   Active Min                   692703 non-null  int64
#  74  Idle Mean                     692703 non-null  float64
#  75   Idle Std                     692703 non-null  float64
#  76   Idle Max                     692703 non-null  int64
#  77   Idle Min                     692703 non-null  int64
#  78   Label                        692703 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 417.5+ MB
# None

# %%
#basic statistics - includes statistical measures like mean,median,standard deviation,min,and max for numerical columns.
print("Basic statistics:")
print(df.describe())
# Out:
# Basic statistics:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      692703.000000    6.927030e+05       692703.000000
# mean         5686.869462    2.800168e+07            9.556261
# std         15727.423560    4.276680e+07          747.197814
# min             0.000000   -1.000000e+00            1.000000
# 25%            53.000000    2.010000e+02            2.000000
# 50%            80.000000    6.143700e+04            2.000000
# 75%           443.000000    8.302437e+07            7.000000
# max         65487.000000    1.200000e+08       203943.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            692703.000000                 6.927030e+05
# mean                 10.214079                 5.550930e+02
# std                 984.204633                 6.163663e+03
# min                   0.000000                 0.000000e+00
# 25%                   1.000000                 1.200000e+01
# 50%                   2.000000                 8.200000e+01
# 75%                   6.000000                 3.650000e+02
# max              272353.000000                 1.224076e+06
#
#         Total Length of Bwd Packets   Fwd Packet Length Max  \
# count                  6.927030e+05           692703.000000
# mean                   1.699644e+04              233.593936
# std                    2.241175e+06              603.751856
# min                    0.000000e+00                0.000000
# 25%                    0.000000e+00                6.000000
# 50%                    1.880000e+02               46.000000
# 75%                    1.159500e+04              341.000000
# max                    6.270000e+08            24820.000000
#
#         Fwd Packet Length Min   Fwd Packet Length Mean  \
# count           692703.000000            692703.000000
# mean                15.022183                60.555440
# std                 51.068835               157.643794
# min                  0.000000                 0.000000
# 25%                  0.000000                 6.000000
# 50%                  0.000000                41.000000
# 75%                 32.000000                56.666667
# max               2065.000000              4640.757576
#
#         Fwd Packet Length Std  ...   act_data_pkt_fwd   min_seg_size_forward  \
# count           692703.000000  ...      692703.000000          692703.000000
# mean                82.895863  ...           6.121279              26.761141
# std                226.126084  ...         715.155068               6.322368
# min                  0.000000  ...           0.000000              -1.000000
# 25%                  0.000000  ...           0.000000              20.000000
# 50%                  0.000000  ...           1.000000              32.000000
# 75%                128.916917  ...           2.000000              32.000000
# max               6429.190773  ...      197124.000000              60.000000
#
#         Active Mean    Active Std    Active Max    Active Min     Idle Mean  \
# count  6.927030e+05  6.927030e+05  6.927030e+05  6.927030e+05  6.927030e+05
# mean   9.224478e+04  4.760852e+04  1.627363e+05  6.315186e+04  2.211122e+07
# std    7.007049e+05  4.742081e+05  1.094616e+06  6.051023e+05  3.812415e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    9.910000e+02  0.000000e+00  9.910000e+02  9.880000e+02  1.590000e+07
# max    1.000000e+08  7.420000e+07  1.050000e+08  1.000000e+08  1.200000e+08
#
#            Idle Std      Idle Max      Idle Min
# count  6.927030e+05  6.927030e+05  6.927030e+05
# mean   4.743744e+05  2.252174e+07  2.173373e+07
# std    4.488512e+06  3.848292e+07  3.807725e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  1.650000e+07  1.000000e+07
# max    7.690000e+07  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
#labels and count in each
df[' Label'].value_counts()
# Out:
#  Label
# BENIGN              440031
# DoS Hulk            231073
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Heartbleed              11
# Name: count, dtype: int64

# %%
'''
Observations from Data Exploration
- Dataset contains both normal and attack traffic.
- Dataset is large with many correlated numerical features.
- Only 1 categorical feature - 'Label'
- This understanding helps define cleaning and preprocessing steps.
'''
# Out:
# "\nObservations from Data Exploration\n- Dataset contains both normal and attack traffic.\n- Dataset is large with many correlated numerical features.\n- Only 1 categorical feature - 'Label'\n- This understanding helps define cleaning and preprocessing steps.\n"

# %%
#identifying missing values to identify incomplete data that may affect model accuracy
missing_before = df.isnull().sum()
print("Missing values:")
print(missing_before[missing_before > 0])
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage[missing_percentage > 0])
# Out:
# Missing values:
# Flow Bytes/s    1008
# dtype: int64
# Flow Bytes/s    0.145517
# dtype: float64

# %%
#visualize missing value
import seaborn as sns
import matplotlib.pyplot as plt
# Heatmap to visualize missing values
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
df['Flow Bytes/s'].isna().value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Flow Bytes/s'>

# %%
#2. Data Cleaning and Preprocessing

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("Categorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: Index([' Label'], dtype='object')
# Numerical columns: Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min'],
#       dtype='object')

# %%
import numpy as np

# replace inf and -inf with NaN
df[numerical_cols] = df[numerical_cols].replace([np.inf, -np.inf], np.nan)

# %%
#Impute NaN values with median
for col in numerical_cols:
    df[col] = df[col].fillna(df[col].median())

# Verify
print("Missing values after handling:")
print(df[numerical_cols].isnull().sum())
# Out:
# Missing values after handling:
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
#                               ..
#  Active Min                    0
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
# Length: 78, dtype: int64

# %%
#handle duplicate rows to avoid data bias
print("Number of duplicate rows:", df.duplicated().sum())
df = df.drop_duplicates()
print("After dropping duplicates:", df.shape)
# Out:
# Number of duplicate rows: 81909
# After dropping duplicates: (610794, 79)

# %%
#' Destination Port', ' Flow Duration', ' Total Fwd Packets',etc contain leading/tailing spaces, make them hard to us.
# So strip extra spaces in column names to prevent error later
df.columns = df.columns.str.strip()

# %%
#handling irrelevant features
irrelevant_cols = [
    'Fwd Header Length.1',
    'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags',
    'CWE Flag Count', 'ECE Flag Count',
    'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate',
    'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate',
    'min_seg_size_forward',
    'Active Max', 'Active Min', 'Idle Max', 'Idle Min'
]
df = df.drop(columns=irrelevant_cols, errors='ignore')
print("Number of columns after remmoving irrelevant cols:", len(df.columns))
print("Columns:")
print(df.columns.tolist())
# Out:
# Number of columns after remmoving irrelevant cols: 62
# Columns:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'Active Mean', 'Active Std', 'Idle Mean', 'Idle Std', 'Label']

# %%
#save cleaned data
df.to_csv('cleaned_data.csv', index=False)

# %%
#Correlation heatmap of numeric features to understand how strongly they are related
#Only numeric columns as df.corr only works with numeric type
numeric_df = df.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(12,10))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %%
#Detect outliers in all numeric columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
outlier_summary = {}

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outlier_summary[col] = len(outliers)

# Convert to DataFrame for easier viewing
outlier_df = pd.DataFrame.from_dict(outlier_summary, orient='index', columns=['Num_Outliers'])
outlier_df = outlier_df.sort_values(by='Num_Outliers', ascending=False)
print(outlier_df)
total_outliers = outlier_df['Num_Outliers'].sum()
print("\nTotal number of outliers in all numeric columns:", total_outliers)
# Out:
#                 Num_Outliers
# Fwd Packets/s         139977
# Flow Packets/s        137714
# Fwd IAT Min           137230
# Flow Bytes/s          136537
# Bwd IAT Total         135621
# ...                      ...
# Flow Duration              0
# Fwd IAT Max                0
# Fwd IAT Total              0
# ACK Flag Count             0
# Idle Mean                  0
#
# [61 rows x 1 columns]
#
# Total number of outliers in all numeric columns: 2891197

# %%
Q1 = df['Flow Bytes/s'].quantile(0.25)
Q3 = df['Flow Bytes/s'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['Flow Bytes/s'] < lower_bound) | (df['Flow Bytes/s'] > upper_bound)]
print("Number of outliers in Flow Bytes/s:", len(outliers))
# Out:
# Number of outliers in Flow Bytes/s: 136537

# %%
#checking outliers in flowbytes/s
plt.figure(figsize=(12,6))
sns.boxplot(x=df['Flow Bytes/s'])
plt.title("Boxplot of Flow Bytes/s")
plt.show()

# %%
# Find columns where all values are 0
all_zero_cols = df.columns[(df == 0).all()]
print("Columns with all zero values:")
print(all_zero_cols.tolist())
# Out:
# Columns with all zero values:
# []

# %%
#3. Feature Engineering and Selection

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Label_encoded'] = le.fit_transform(df['Label'])
label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Label Encoding Mapping:", label_mapping)
# Out:
# Label Encoding Mapping: {'BENIGN': np.int64(0), 'DoS GoldenEye': np.int64(1), 'DoS Hulk': np.int64(2), 'DoS Slowhttptest': np.int64(3), 'DoS slowloris': np.int64(4), 'Heartbleed': np.int64(5)}

# %%
# Visualize the distribution of Label classes
plt.figure(figsize=(8,5))
sns.countplot(x='Label', data=df)
plt.title("Distribution of Label Classes")
plt.xticks(rotation=45)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'Active Mean', 'Active Std', 'Idle Mean', 'Idle Std', 'Label', 'Label_encoded']

# %%
# Select only numerical columns from your important features
num_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
num_features = [col for col in num_features if col != 'Label']  # exclude target label

plt.figure(figsize=(18,15))
for i, col in enumerate(num_features[:9], 1):  # visualize first 9 features (to avoid clutter)
    plt.subplot(3, 3, i)
    sns.histplot(df[col], kde=True, bins=50)
    plt.title(f"Distribution of {col}")
plt.tight_layout()
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'Active Mean', 'Active Std', 'Idle Mean', 'Idle Std', 'Label', 'Label_encoded']

# %%
#save encoded and cleaned dataset
df_encoded = df.drop(columns=['Label']) #since label encoded col exist
df_encoded.to_csv('/content/sentinelnet_encoded.csv', index=False)
print("Encoded dataset saved successfully!")
# Out:
# Encoded dataset saved successfully!

# %%
#load cleaned and encoded dataset
df = pd.read_csv('/content/sentinelnet_encoded.csv')
print("Encoded dataset loaded successfully with shape:", df.shape)

# Separate features and target variable
X = df.drop(columns=['Label_encoded'], errors='ignore')
y = df['Label_encoded']

print("Feature matrix shape:", X.shape)
print("Target vector shape:", y.shape)
# Out:
# Encoded dataset loaded successfully with shape: (610794, 62)
# Feature matrix shape: (610794, 61)
# Target vector shape: (610794,)

# %%
#feature scaling using StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Feature scaling completed successfully!")
# Out:
# Feature scaling completed successfully!

# %%
#applying PCA to reduce no. of dimensions while keeping most of dataset's info
from sklearn.decomposition import PCA

# Keep 95% of total variance
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_scaled)

print("Original feature count:", X.shape[1])
print("Reduced feature count after PCA:", X_pca.shape[1])
# Out:
# Original feature count: 61
# Reduced feature count after PCA: 21

# %%
#save PCA-transformed dataset
X_pca_df = pd.DataFrame(X_pca)
X_pca_df['Label'] = y.values
X_pca_df.to_csv('/content/sentinelnet_pca.csv', index=False)

print("PCA-transformed dataset saved successfully!")
# Out:
# PCA-transformed dataset saved successfully!

# %%
#splitting dataset into train(70%) and test(30%)
from sklearn.model_selection import train_test_split

# Using scaled data (before PCA) for feature importance
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (427555, 61)
# Testing set shape: (183239, 61)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf_model = RandomForestClassifier(n_estimators=50, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, rf_pred))
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.9991759396198407
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    125219
#            1       1.00      1.00      1.00      3043
#            2       1.00      1.00      1.00     51822
#            3       1.00      0.99      0.99      1553
#            4       0.99      1.00      0.99      1598
#            5       1.00      1.00      1.00         4
#
#     accuracy                           1.00    183239
#    macro avg       1.00      1.00      1.00    183239
# weighted avg       1.00      1.00      1.00    183239

# %%
#extract and display feature importance
feature_importances = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

top10_features = feature_importances.head(10)
print("Top 10 Important Features:\n")
print(top10_features)
# Out:
# Top 10 Important Features:
#
#                         Feature  Importance
# 13        Bwd Packet Length Std    0.089195
# 5   Total Length of Bwd Packets    0.079366
# 10        Bwd Packet Length Max    0.074274
# 12       Bwd Packet Length Mean    0.073515
# 39       Packet Length Variance    0.068462
# 36            Max Packet Length    0.047446
# 38            Packet Length Std    0.047185
# 23                  Fwd IAT Max    0.045805
# 37           Packet Length Mean    0.043623
# 59                    Idle Mean    0.037193

# %%
#visualize top 10 important features
plt.figure(figsize=(8,5))
sns.barplot(x='Importance', y='Feature', data=top10_features, palette='coolwarm')
plt.title('Top 10 Important Features (Random Forest)')
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.show()
# Out:
# /tmp/ipython-input-3530965275.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=top10_features, palette='coolwarm')

# %%
'''
graph overview
The graph above shows the top 10 factors that helped the model make its decisions.
Each bar represents how important that factor was.The longer the bar, the more influence it had on the result.
For eg, Bwd Packet Length Std and Total Length of Bwd Packets were the most important factors.
In simple terms, this means that the size and variation of data packets moving through the network played a big role in how the system learned to tell normal activity from unusual activity.
'''
# Out:
# '\ngraph overview\nThe graph above shows the top 10 factors that helped the model make its decisions.\nEach bar represents how important that factor was.The longer the bar, the more influence it had on the result.\nFor eg, Bwd Packet Length Std and Total Length of Bwd Packets were the most important factors.\nIn simple terms, this means that the size and variation of data packets moving through the network played a big role in how the system learned to tell normal activity from unusual activity.\n'

# %%
#save top 10 features
top10_features.to_csv('/content/top10_features.csv', index=False)
print("Top 10 important features saved successfully")
# Out:
# Top 10 important features saved successfully

# %%
from sklearn.svm import SVC

# Initialize SVM model
svm_model = SVC(kernel='rbf', random_state=42)

# Train SVM model
svm_model.fit(X_train, y_train)

# Predictions
svm_pred = svm_model.predict(X_test)

# Evaluate
from sklearn.metrics import accuracy_score, classification_report

print("SVM Accuracy:", accuracy_score(y_test, svm_pred))
print(classification_report(y_test, svm_pred))
# Out:
# SVM Accuracy: 0.9893254165325067
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    125219
#            1       0.99      0.93      0.96      3043
#            2       0.97      1.00      0.99     51822
#            3       0.96      0.97      0.96      1553
#            4       0.99      0.93      0.95      1598
#            5       1.00      0.75      0.86         4
#
#     accuracy                           0.99    183239
#    macro avg       0.98      0.93      0.95    183239
# weighted avg       0.99      0.99      0.99    183239

# %%
from sklearn.linear_model import LogisticRegression

# Initialize model
lr_model = LogisticRegression(max_iter=1000, random_state=42)

# Train
lr_model.fit(X_train, y_train)

# Predict
lr_pred = lr_model.predict(X_test)

# Evaluate
print("Logistic Regression Accuracy:", accuracy_score(y_test, lr_pred))
print(classification_report(y_test, lr_pred))
# Out:
# Logistic Regression Accuracy: 0.9921304962371548
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    125219
#            1       0.98      0.91      0.94      3043
#            2       0.99      1.00      0.99     51822
#            3       0.92      0.92      0.92      1553
#            4       0.92      0.90      0.91      1598
#            5       1.00      0.75      0.86         4
#
#     accuracy                           0.99    183239
#    macro avg       0.97      0.91      0.94    183239
# weighted avg       0.99      0.99      0.99    183239
